# %% [markdown]
# # Máster en Big Data y Data Science
#
# # Metodologías de gestión y diseño de proyectos de big data
#
# ## Actividad Guiada II - Actividades de Preparación de los Datos
#
# ---
#
# ### Sprint 1

# %% [markdown]
# ### Carga de librerias a utilizar

# %%
pip install dtale

# %%
# Se importan las librerias a utilizar
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import dtale
import requests
import dtale.app as dtale_app

dtale_app.USE_COLAB = True

# %matplotlib inline

# %% [markdown]
# ### Lectura de los datasets

# %%
# Se hace la lectura de los datasets modificados en el seminario y se obtiene una vista

#df_inscripciones = pd.read_csv('../datasets/datos_inscripciones_mod.csv', sep=';')
url_inscripciones="https://raw.githubusercontent.com/JulietaNova/13MBID/main/datos_inscripciones_mod.csv"
df_inscripciones = pd.read_csv(url_inscripciones, sep=';')
display(df_inscripciones.head(1))

#df_cursado = pd.read_csv('../datasets/datos_cursado_mod.csv', sep=';')
url_cursado="https://raw.githubusercontent.com/JulietaNova/13MBID/main/datos_cursado_mod.csv"
df_cursado = pd.read_csv(url_cursado, sep=';')
display(df_cursado.head(1))

#df_academicos = pd.read_csv('../datasets/datos_academicos_mod.csv', sep=';')
url_academicos="https://raw.githubusercontent.com/JulietaNova/13MBID/main/datos_academicos_mod.csv"
df_academicos=pd.read_csv(url_academicos, sep=';')
display(df_academicos.head(1))
# Out:
#   id_estudiante  propuesta estado_inscripcion plan_estudios  version_plan  \
# 0   CA-015876-9        130          Pendiente          2007            14
#
#     modalidad fecha_ingreso fecha_inscripcion  err_formato_matricula  \
# 0  Presencial    01/04/2020        04/12/2019                   True
#
#   regla_fechas_ingreso
# 0                   ok
#   id_estudiante estado_inscripcion  ingreso_aprobadas  ingreso_libres  \
# 0   CA-015876-9          Pendiente                  2               0
#
#    ingreso_totales  cursadas_aprobadas  cursadas_regulares  cursadas_libres  \
# 0                2                   0                   0                0
#
#    cursadas_totales  inscripciones_examenes  examenes_aprobados  \
# 0                 3                       0                   0
#
#    err_formato_matricula regla_estado_inscripcion
# 0                   True                       ok
#   id_estudiante  plan  anio_ingreso fecha_ingreso fecha_ultimo_examen  \
# ...

# %% [markdown]
# ### Selección de atributos
#
# Los atributos de las reglas generadas en la fase de comprensión de los datos son:
#
# * err_formato_matricula (**todos**)
# * regla_fechas_ingreso (**inscripciones**)
# * regla_estado_inscripcion (**cursado**)
# * regla_verificacion_calidad (**academicos**)

# %%
col_eliminar_inscripciones = ['plan_estudios', 'version_plan', 'modalidad',
                                'err_formato_matricula']
col_eliminar_academico = ['plan', 'fecha_ingreso', 'err_formato_matricula']

# %%
df_inscripciones.drop(col_eliminar_inscripciones, inplace=True, axis=1)
df_academicos.drop(col_eliminar_academico, inplace=True, axis=1)

# %%
col_eliminar_cursado = ['err_formato_matricula']
df_cursado.drop(col_eliminar_cursado, inplace=True, axis=1)

# %%
print("Vista del dataset de inscripciones modificado:")
display(df_inscripciones.head(1))

print("Vista del dataset de datos académicos modificado:")
display(df_academicos.head(1))

print("Vista del dataset de datos de cursado modificado:")
display(df_cursado.head(1))
# Out:
# Vista del dataset de inscripciones modificado:
#   id_estudiante  propuesta estado_inscripcion fecha_ingreso fecha_inscripcion  \
# 0   CA-015876-9        130          Pendiente    01/04/2020        04/12/2019
#
#   regla_fechas_ingreso
# 0                   ok
# Vista del dataset de datos académicos modificado:
#   id_estudiante  anio_ingreso fecha_ultimo_examen  anio_ultima_reinscripcion  \
# 0   CB-015914-6          2020                 NaN                     2021.0
#
#    promedio_sin_aplazos  promedio_con_aplazos  actividades_aprobadas  \
# 0                   8.0                   8.0                      2
#
#    total_actividades regular calidad segundo_anio regla_verificacion_calidad
# 0                 40       S       A            N                         ok
# Vista del dataset de datos de cursado modificado:
#   id_estudiante estado_inscripcion  ingreso_aprobadas  ingreso_libres  \
# 0   CA-015876-9          Pendiente                  2               0
#
# ...

# %% [markdown]
# ___
#
# ## Inicio de las actividades de la AG3 (dictado 2023)
#
# ### Limpieza de los datos

# %%
# Se eliminan las filas que no cumplen con las reglas del negocio

# Datos de inscripciones

# Se aplica la limpieza
temp = df_inscripciones[df_inscripciones.regla_fechas_ingreso != 'err']

limpiar_columnas = ['regla_fechas_ingreso']
df_inscripciones_a = temp.drop(limpiar_columnas, axis=1)

print(f"Filas resultantes: {df_inscripciones_a.shape[0]} - Total original: {df_inscripciones.shape[0]} ")
df_inscripciones_a.head(5)
# Out:
# Filas resultantes: 1286 - Total original: 1332
#   id_estudiante  propuesta estado_inscripcion fecha_ingreso fecha_inscripcion
# 0   CA-015876-9        130          Pendiente    01/04/2020        04/12/2019
# 1   CB-015876-0        134          Pendiente    01/04/2020        04/12/2019
# 2   CA-016187-5        130          Pendiente    01/04/2020        09/12/2019
# 3   CA-016558-7        130          Pendiente    01/04/2020        10/02/2020
# 4   CA-016079-8        130          Pendiente    01/04/2020        17/12/2019

# %%
# Datos de cursado

# Se aplica la limpieza
temp = df_cursado[df_cursado.regla_estado_inscripcion != 'err']

limpiar_columnas = ['regla_estado_inscripcion', 'estado_inscripcion']

df_cursado_a = temp.drop(limpiar_columnas, axis=1)

print(f"Filas resultantes: {df_cursado_a.shape[0]}  - Total original: {df_cursado.shape[0]}")
df_cursado_a.head(5)
# Out:
# Filas resultantes: 1320  - Total original: 1332
#   id_estudiante  ingreso_aprobadas  ingreso_libres  ingreso_totales  \
# 0   CA-015876-9                  2               0                2
# 1   CB-015876-0                  2               0                2
# 2   CA-016187-5                  2               0                2
# 3   CA-016558-7                  2               0                2
# 4   CA-016079-8                  2               0                2
#
#    cursadas_aprobadas  cursadas_regulares  cursadas_libres  cursadas_totales  \
# 0                   0                   0                0                 3
# 1                   0                   0                0                 3
# 2                   0                   0                0                 3
# 3                   0                   0                0                 3
# 4                   0                   0                0                 3
#
# ...

# %%
# Datos académicos

# Se aplica la limpieza
temp = df_academicos[df_academicos.regla_verificacion_calidad != 'err']

limpiar_columnas = ['regla_verificacion_calidad']
df_academicos_a = temp.drop(limpiar_columnas, axis=1)

print(f"Filas resultantes: {df_academicos_a.shape[0]} - Total original: {df_academicos.shape[0]}")
df_academicos_a.head(5)
# Out:
# Filas resultantes: 618 - Total original: 815
#   id_estudiante  anio_ingreso fecha_ultimo_examen  anio_ultima_reinscripcion  \
# 0   CB-015914-6          2020                 NaN                     2021.0
# 1   CB-015898-1          2020          23/08/2021                     2021.0
# 2   CB-015876-0          2020          23/08/2021                     2021.0
# 3   CB-015788-7          2020                 NaN                     2021.0
# 4   CB-015884-1          2020          18/08/2021                     2021.0
#
#    promedio_sin_aplazos  promedio_con_aplazos  actividades_aprobadas  \
# 0                  8.00                  8.00                      2
# 1                  6.80                  8.00                      4
# 2                  6.40                  6.40                      5
# 3                  7.50                  7.50                      2
# 4                  7.67                  7.67                     10
#
# ...

# %% [markdown]
# ### Confirmación de existencia de valores nulos

# %%
#Dataset: datos_inscripciones

nulos_x_columna = df_inscripciones_a.isna().sum()

print(f"Cantidad de filas que tienen valores nulos por atributo:\n{nulos_x_columna}")
# Out:
# Cantidad de filas que tienen valores nulos por atributo:
# id_estudiante         0
# propuesta             0
# estado_inscripcion    0
# fecha_ingreso         0
# fecha_inscripcion     0
# dtype: int64

# %%
#Dataset: datos_cursado

nulos_x_columna = df_cursado_a.isna().sum()

print(f"Cantidad de filas que tienen valores nulos por atributo:\n{nulos_x_columna}")
# Out:
# Cantidad de filas que tienen valores nulos por atributo:
# id_estudiante             0
# ingreso_aprobadas         0
# ingreso_libres            0
# ingreso_totales           0
# cursadas_aprobadas        0
# cursadas_regulares        0
# cursadas_libres           0
# cursadas_totales          0
# inscripciones_examenes    0
# examenes_aprobados        0
# dtype: int64

# %%
#Dataset: datos_academicos

nulos_x_columna = df_academicos_a.isna().sum()

print(f"Cantidad de filas que tienen valores nulos por atributo:\n{nulos_x_columna}")
# Out:
# Cantidad de filas que tienen valores nulos por atributo:
# id_estudiante                  0
# anio_ingreso                   0
# fecha_ultimo_examen          406
# anio_ultima_reinscripcion    206
# promedio_sin_aplazos           0
# promedio_con_aplazos           0
# actividades_aprobadas          0
# total_actividades              0
# regular                        0
# calidad                        0
# segundo_anio                   0
# dtype: int64

# %% [markdown]
# ### Construcción de atributos

# %% [markdown]
# **Atributo 1 a generar:** grado de cumplimiento de actividades

# %%
df_academicos_a.iloc[1]
# Out:
# id_estudiante                CB-015898-1
# anio_ingreso                        2020
# fecha_ultimo_examen           23/08/2021
# anio_ultima_reinscripcion         2021.0
# promedio_sin_aplazos                 6.8
# promedio_con_aplazos                 8.0
# actividades_aprobadas                  4
# total_actividades                     40
# regular                                S
# calidad                                A
# segundo_anio                           N
# Name: 1, dtype: object

# %%
# actividades / total = % de avance en la carrera

def pct_avance_carrera(row):
    return row.actividades_aprobadas / row.total_actividades

avance_carrera = df_academicos_a.apply(lambda row: pct_avance_carrera(row), axis=1).rename('avance_carrera')
avance_carrera
# Out:
# 0      0.050000
# 1      0.100000
# 2      0.125000
# 3      0.050000
# 4      0.250000
#          ...
# 809    0.190476
# 811    0.904762
# 812    0.309524
# 813    0.880952
# 814    0.119048
# Name: avance_carrera, Length: 618, dtype: float64

# %%
df_cursado_a.iloc[1]
# Out:
# id_estudiante             CB-015876-0
# ingreso_aprobadas                   2
# ingreso_libres                      0
# ingreso_totales                     2
# cursadas_aprobadas                  0
# cursadas_regulares                  0
# cursadas_libres                     0
# cursadas_totales                    3
# inscripciones_examenes              0
# examenes_aprobados                  0
# Name: 1, dtype: object

# %%
# cursadas libres (asignaturas perdidas) / total asignaturas = % de asignaturas perdidas primer cuatrimestre

def pct_asignaturas_perdidas(row):
    return row.cursadas_libres / row.cursadas_totales

asignaturas_perdidas = df_cursado_a.apply(lambda row: pct_asignaturas_perdidas(row), axis=1).rename('asignaturas_perdidas')
asignaturas_perdidas
# Out:
# 0       0.000000
# 1       0.000000
# 2       0.000000
# 3       0.000000
# 4       0.000000
#           ...
# 1327    0.000000
# 1328    0.333333
# 1329    1.000000
# 1330    0.666667
# 1331    1.000000
# Name: asignaturas_perdidas, Length: 1320, dtype: float64

# %% [markdown]
# **TODO:** evaluar la generación de otros atributos

# %%
# Vista de otros atributos

#academicos_a.anio_ultima_reinscripcion.value_counts()

df_academicos_a.calidad.value_counts()
# Out:
# A    412
# P    206
# Name: calidad, dtype: int64

# %% [markdown]
# ### Integración de los datos

# %%
#Las uniones se hacen de a pares - revisar nombres de atributos

cantidad_filas = df_inscripciones_a.shape[0]

inscripciones_x_cursadas = pd.merge(df_inscripciones_a, df_cursado_a, on='id_estudiante', how='inner')
coincidencias_uno = inscripciones_x_cursadas.shape[0]

print(f"Datos de inscripciones: {cantidad_filas} - Coincidencias con datos de cursado: {coincidencias_uno}")
# Out:
# Datos de inscripciones: 1286 - Coincidencias con datos de cursado: 1275

# %%
#Para verificar visualmente se puede ejecutar

inscripciones_x_cursadas.head(5)
# Out:
#   id_estudiante  propuesta estado_inscripcion fecha_ingreso fecha_inscripcion  \
# 0   CA-015876-9        130          Pendiente    01/04/2020        04/12/2019
# 1   CB-015876-0        134          Pendiente    01/04/2020        04/12/2019
# 2   CA-016187-5        130          Pendiente    01/04/2020        09/12/2019
# 3   CA-016558-7        130          Pendiente    01/04/2020        10/02/2020
# 4   CA-016079-8        130          Pendiente    01/04/2020        17/12/2019
#
#    ingreso_aprobadas  ingreso_libres  ingreso_totales  cursadas_aprobadas  \
# 0                  2               0                2                   0
# 1                  2               0                2                   0
# 2                  2               0                2                   0
# 3                  2               0                2                   0
# 4                  2               0                2                   0
#
# ...

# %%
#Las uniones se hacen de a pares - revisar nombres de atributos

datos_completos = pd.merge(inscripciones_x_cursadas, df_academicos_a, on='id_estudiante', how='inner')

# Se visualiza el dataset unificado

datos_completos.head()
# Out:
#   id_estudiante  propuesta estado_inscripcion fecha_ingreso fecha_inscripcion  \
# 0   CB-015876-0        134          Pendiente    01/04/2020        04/12/2019
# 1   CA-016187-5        130          Pendiente    01/04/2020        09/12/2019
# 2   CA-016558-7        130          Pendiente    01/04/2020        10/02/2020
# 3   CA-016164-6        130          Pendiente    01/04/2020        02/12/2019
# 4   CA-016551-0        130           Aceptado    01/04/2020        10/02/2020
#
#    ingreso_aprobadas  ingreso_libres  ingreso_totales  cursadas_aprobadas  \
# 0                  2               0                2                   0
# 1                  2               0                2                   0
# 2                  2               0                2                   0
# 3                  0               2                2                   0
# 4                  1               1                2                   0
#
# ...

# %%
print(f"Datos de inscripciones: {cantidad_filas} - Datos de cursado: {df_cursado_a.shape[0]} - Coincidencias entre inscripciones y cursado: {coincidencias_uno}")

print(f"Datos completos: {datos_completos.shape[0]} integrando todas las fuentes")

datos_completos.shape[1]
# Out:
# Datos de inscripciones: 1286 - Datos de cursado: 1320 - Coincidencias entre inscripciones y cursado: 1275
# Datos completos: 582 integrando todas las fuentes
# 24

# %%
datos_completos.count()
# Out:
# id_estudiante                582
# propuesta                    582
# estado_inscripcion           582
# fecha_ingreso                582
# fecha_inscripcion            582
# ingreso_aprobadas            582
# ingreso_libres               582
# ingreso_totales              582
# cursadas_aprobadas           582
# cursadas_regulares           582
# cursadas_libres              582
# cursadas_totales             582
# inscripciones_examenes       582
# examenes_aprobados           582
# anio_ingreso                 582
# fecha_ultimo_examen          202
# anio_ultima_reinscripcion    378
# promedio_sin_aplazos         582
# promedio_con_aplazos         582
# actividades_aprobadas        582
# total_actividades            582
# regular                      582
# calidad                      582
# segundo_anio                 582
# dtype: int64

# %% [markdown]
# ### Exploración del dataset resultante

# %%
def reporte_descripcion_dataset(df):
    columnas = df.columns
    print("Columnas del dataset:\n")
    for col in columnas:
        print(col)
    print(f"\nCantidad de filas: {df.shape[0]}")

print("Descripción del dataset 'datos_completos'")
reporte_descripcion_dataset(datos_completos)
# Out:
# Descripción del dataset 'datos_completos'
# Columnas del dataset:
#
# id_estudiante
# propuesta
# estado_inscripcion
# fecha_ingreso
# fecha_inscripcion
# ingreso_aprobadas
# ingreso_libres
# ingreso_totales
# cursadas_aprobadas
# cursadas_regulares
# cursadas_libres
# cursadas_totales
# inscripciones_examenes
# examenes_aprobados
# anio_ingreso
# fecha_ultimo_examen
# anio_ultima_reinscripcion
# promedio_sin_aplazos
# promedio_con_aplazos
# actividades_aprobadas
# total_actividades
# regular
# calidad
# segundo_anio
#
# Cantidad de filas: 582

# %% [markdown]
# #### Vista de meta-datos del dataset

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import dtale
import dtale.app as dtale_app

dtale_app.USE_COLAB = True
# %matplotlib inline

# %%
# comp = dtale.show(datos_completos)
# comp.open_browser()
dtale.show(datos_completos)
# Out:
# https://oyd82z808a-496ff2e9c6d22116-40000-colab.googleusercontent.com/dtale/main/9

# %% [markdown]
# #### Exportación a disco del dataset

# %%
# Se escribe a disco el dataset resultante

from google.colab import files
datos_completos.to_csv('datos_completos.csv', sep=';', index=False)
files.download('datos_completos.csv')
print(f"Cantidad de filas: {datos_completos.shape[0]}")
print(f"Cantidad de columnas: {datos_completos.shape[1]}")
# Out:
# Cantidad de filas: 582
# Cantidad de columnas: 24
